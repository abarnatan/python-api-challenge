# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
readcsv = pd.read_csv("Output/weather_df.csv")
readcsv.head()

del readcsv["Unnamed: 0"]

readcsv.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        nyurba          11      RU  1604279755        90  63.28  118.33
# 1        majene         100      ID  1604279755        70  -3.54  118.97
# 2   new norfolk          12      LR  1604279628        97   6.65  -10.59
# 3  saint-joseph          90      RE  1604279755        56 -21.37   55.62
# 4      hermanus          80      ZA  1604279592        81 -34.42   19.23
#
#    Max Temp  Wind Speed
# 0      1.98        9.89
# 1     83.84        7.38
# 2     74.08        2.59
# 3     69.80        5.82
# 4     64.00       10.00

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure GMAPS 
gmaps.configure(api_key = g_key)

# %%
# Create variables to store data
locations = readcsv[["Lat","Lng"]]
weight = readcsv["Humidity"]

# %%
# Create heatmap 
fig = gmaps.figure(center=(20,1), zoom_level = 1.5)
heat_layer = gmaps.heatmap_layer(locations,weight, dissipating = False, max_intensity = 300, point_radius = 6)

# Add heat layer to fig 
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Clean data to show ideal vacation locations
ideal_cities = readcsv.loc[(readcsv["Max Temp"] > 65) & (readcsv["Max Temp"] < 90)]
ideal_cities = ideal_cities.loc[(readcsv["Wind Speed"] < 10)]
ideal_cities = ideal_cities.loc[(readcsv["Cloudiness"] == 0)]
ideal_cities = ideal_cities.dropna()
ideal_cities.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 25       hobart           0      AU  1604279661        56 -42.88  147.33
# 66         kaya           0      BF  1604279774        21  13.09   -1.08
# 83   ouahigouya           0      BF  1604279779        16  13.58   -2.42
# 91        segou           0      ML  1604279783        19  13.43   -6.22
# 102  kolondieba           0      ML  1604279786        39  11.09   -6.89
#
#      Max Temp  Wind Speed
# 25      73.99        9.17
# 66      78.94        6.91
# 83      80.65        9.26
# 91      77.05        4.70
# 102     75.34        2.73

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = ideal_cities.loc[:, ["City", "Country","Lat","Lng"]]
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#            City Country    Lat     Lng Hotel Name
# 25       hobart      AU -42.88  147.33
# 66         kaya      BF  13.09   -1.08
# 83   ouahigouya      BF  13.58   -2.42
# 91        segou      ML  13.43   -6.22
# 102  kolondieba      ML  11.09   -6.89

# %%
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
parameters = {
    "radius" : 5000,
    "type" : "hotel",
    "key" : g_key
}
parameters["location"] = f"63.28, 118.33"
hotels = requests.get(url, params = parameters).json()
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AcnaJv18NagPWUYqnT1kD4huj-1D41fVjypgXbuazKBdz0-u7BJSnaHiehOCelQVdb7Wu6C8MuwqTPkca9MgeUzEigyZRC9jJvbbijaoTrHqfhjx76pS1WOXyBn47GUYsnngSUH0lWNQdxtOyDu2-KBnXTByVh-hu0OTeLc9eHda83oCDUIo52h0GQpOdQn-t0P_ClmYP6RSfK0ZW7FOLzp6oUtRpytsiA_RgKILrIpx6DGLHlhAKn3IIQIkxDO6TKA8kyYMtYWdh7rKaf0TI2fBVclWx1ADI013aqaO5QctO4GxeYfSgcG-TPewhg6IiVAV-TJOp-pwftPOreZYWnnSxeUTUnNTm1V48Qvh50CXBBgBJnk5wT3KfqazipfSygTkmgHQWWGQ0I8m4da51YORvxHFXHhw1WcB9drFdByo39vU6FrH',
#  'results': [{'geometry': {'location': {'lat': 63.2803099, 'lng': 118.3618985},
#     'viewport': {'northeast': {'lat': 63.29362, 'lng': 118.3954691},
#      'southwest': {'lat': 63.27218689999999, 'lng': 118.3291251}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#    'name': 'Nyurba',
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109476850921786658997">Анастасия Юшкевич</a>'],
#      'photo_reference': 'CmRaAAAAhCp2H1X6Cx5DBQtmsOPql1zBtO0C7kXgdodvTgMYJEuYMdDEM5KdCyXKy5LiR33R59oOJWN_IS-G13cxo0KRTFWAhgCRaaeBMixFYvZQywvENghDl6VyKUFk0hxaVOx2EhBRJMQ4xhZPKfze2faAAb_RGhQbQDSdt5TxemDy3iYuDshRHoQwag',
#      'width': 6000}],
#    'place_id': 'ChIJ7z6ykm_keVwRPAB03tqwNXU',
#    'reference': 'ChIJ7z6ykm_keVwRPAB03tqwNXU',
#    'scope': 'GOOGLE',
#    'types': ['locality', 'political'],
#    'vicinity': 'Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2823417, 'lng': 118.3405449},
#     'viewport': {'northeast': {'lat': 63.2837737802915,
#       'lng': 118.3418133802915},
#      'southwest': {'lat': 63.28107581970849, 'lng': 118.3391154197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Rosgosstrakh',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJkREh5e_CeVwRGJDIz9WGLLE',
#    'plus_code': {'compound_code': '78JR+W6 Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78JR+W6'},
#    'rating': 3.7,
#    'reference': 'ChIJkREh5e_CeVwRGJDIz9WGLLE',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 18,
#    'vicinity': "Ulitsa Stepana Vasil'yeva, 62, Nyurba"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2784749, 'lng': 118.3323964},
#     'viewport': {'northeast': {'lat': 63.27953463029151,
#       'lng': 118.3339225302915},
#      'southwest': {'lat': 63.2768366697085, 'lng': 118.3312245697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'name': 'Нюрбинская Средняя Общеобразовательная Школа № 1',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJCXgPi2TkeVwR0XrJQxDFy5A',
#    'plus_code': {'compound_code': '78HJ+9X Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78HJ+9X'},
#    'rating': 4.2,
#    'reference': 'ChIJCXgPi2TkeVwR0XrJQxDFy5A',
#    'scope': 'GOOGLE',
#    'types': ['school', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 18,
#    'vicinity': 'Ulitsa Lenina, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.27850950000001, 'lng': 118.3347661},
#     'viewport': {'northeast': {'lat': 63.2796929302915,
#       'lng': 118.3362242302915},
#      'southwest': {'lat': 63.2769949697085, 'lng': 118.3335262697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Gostinitsa Alrosa',
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113012361171033535439">Эмиль Камилов</a>'],
#      'photo_reference': 'CmRaAAAA4eN2KcP5X0xYWyKHaojTD7NqD3xGaELzk_yVfBJimLVL1_XZRVq9ZFwW7-0e6CfPrj8OLn3D5ocqmf2_lVL1cODxDvEm221pgBhaZMXDNhgWHH5JVnB9cpWNOduk8ABjEhAB-r-9pNVkuUgeCJ0vzFP6GhR4YLClXkUb-dVR9kXqpqBSYO28Zg',
#      'width': 4160}],
#    'place_id': 'ChIJoWrZ62TkeVwRUHrwj52Y9ZI',
#    'plus_code': {'compound_code': '78HM+CW Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78HM+CW'},
#    'rating': 4.3,
#    'reference': 'ChIJoWrZ62TkeVwRUHrwj52Y9ZI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 85,
#    'vicinity': 'Ulitsa Lenina, 23, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.27850950000001, 'lng': 118.3347661},
#     'viewport': {'northeast': {'lat': 63.2796929302915,
#       'lng': 118.3362242302915},
#      'southwest': {'lat': 63.2769949697085, 'lng': 118.3335262697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Oao Alrosa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105729700392347461507">Анисия Илларионова</a>'],
#      'photo_reference': 'CmRaAAAADojUIdWf7KndoW_qRF9p0RjMi46IOeyTYU9M-H7Efg_zMXRAIT1gc_2TaNyowTbK42e0ukXW8HTbgxrb32SgVCOyAxqx-vq0o2SExSj5c7A2MY8k-afcjvHupPs7u7F_EhD-x2l53kqDzryJJ5GgjA3pGhQ1fFxAEQzklxvjM5Z3HrPa5b1VnA',
#      'width': 4000}],
#    'place_id': 'ChIJoWrZ62TkeVwRVLJlvTjh19c',
#    'plus_code': {'compound_code': '78HM+CW Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78HM+CW'},
#    'rating': 5,
#    'reference': 'ChIJoWrZ62TkeVwRVLJlvTjh19c',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Ulitsa Lenina, 23, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2825624, 'lng': 118.3348617},
#     'viewport': {'northeast': {'lat': 63.2839754802915,
#       'lng': 118.3366681302915},
#      'southwest': {'lat': 63.2812775197085, 'lng': 118.3339701697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png',
#    'name': 'Asian-Pacific Bank',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJFUDs5O_CeVwRXysD7UWBijE',
#    'plus_code': {'compound_code': '78MM+2W Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78MM+2W'},
#    'reference': 'ChIJFUDs5O_CeVwRXysD7UWBijE',
#    'scope': 'GOOGLE',
#    'types': ['bank', 'finance', 'point_of_interest', 'establishment'],
#    'vicinity': "Oktyabr'skaya Ulitsa, д. 19, Nyurba"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2815549, 'lng': 118.3376264},
#     'viewport': {'northeast': {'lat': 63.2827804802915,
#       'lng': 118.3390055302915},
#      'southwest': {'lat': 63.28008251970849, 'lng': 118.3363075697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/hospital-71.png',
#    'name': "Nyurbinskaya Tsentral'naya Rayonnaya Bol'nitsa",
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJxVCgnWXkeVwRzCvYg1Mw4to',
#    'plus_code': {'compound_code': '78JQ+J3 Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78JQ+J3'},
#    'rating': 2,
#    'reference': 'ChIJxVCgnWXkeVwRzCvYg1Mw4to',
#    'scope': 'GOOGLE',
#    'types': ['hospital', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'ул. Степана Васильев, 54, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2807719, 'lng': 118.3400697},
#     'viewport': {'northeast': {'lat': 63.28201628029151,
#       'lng': 118.3414827302915},
#      'southwest': {'lat': 63.2793183197085, 'lng': 118.3387847697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png',
#    'name': 'Oao Ak Almazergienbank Do',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111204859462726501736">Lynx Nyurba</a>'],
#      'photo_reference': 'CmRaAAAAXOEs-jb2fpCSwKwOTZ7tRRsj8oPNKNeGR4ebNxIh8yfc51PlevDDDAiNEknxk0AUhdtVEKX4MYUM1dkML2mn7mtYA4rspWH4B_moNfE5kArsQdZJW66FQczXiBp466ngEhDetuRK29HfSjahMHI-b9vDGhSZOW1Aa1aOTlG5ETqwCYWw9tw4Bg',
#      'width': 960}],
#    'place_id': 'ChIJUfJyRWXkeVwRwWEuC9FVrDU',
#    'plus_code': {'compound_code': '78JR+82 Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78JR+82'},
#    'rating': 4.1,
#    'reference': 'ChIJUfJyRWXkeVwRwWEuC9FVrDU',
#    'scope': 'GOOGLE',
#    'types': ['bank', 'atm', 'finance', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': 'Sovetskaya Ulitsa, 65, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.28258529999999, 'lng': 118.3387443},
#     'viewport': {'northeast': {'lat': 63.2837667302915,
#       'lng': 118.3402743802915},
#      'southwest': {'lat': 63.28106876970849, 'lng': 118.3375764197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Pfr V Nyurbinskom Rayone',
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113012361171033535439">Эмиль Камилов</a>'],
#      'photo_reference': 'CmRaAAAAwnFbdIe5_m7BcnSBGXktGh1HUlcfb2ClJMyxdbepSWhiykWZ6-JR-1To01nMBFSz7gf0FpTSHs60JMk8-SK0v3yjtj6FRTX4BNTOeP0jd9DTPPB6zUbeO2DrFUUE95-3EhDWSygCRt313SqvV7pAlSGyGhTfKfNWBvRd5sS9i-jYcBpxxTvtrw',
#      'width': 3120}],
#    'place_id': 'ChIJwXLJhW_keVwR0_4n3jAaQCI',
#    'plus_code': {'compound_code': '78MQ+2F Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78MQ+2F'},
#    'rating': 5,
#    'reference': 'ChIJwXLJhW_keVwR0_4n3jAaQCI',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': "39к2, Ulitsa Stepana Vasil'yeva, 39 корпус 2, Nyurba"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2823667, 'lng': 118.339744},
#     'viewport': {'northeast': {'lat': 63.2836802302915,
#       'lng': 118.3410188302915},
#      'southwest': {'lat': 63.28098226970849, 'lng': 118.3383208697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Svyaznoy',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101949599132143030624">Сан Саныч</a>'],
#      'photo_reference': 'CmRaAAAAXezRE8JhgeFyPhyrTDKU7_JihfBJqUW_UtB9FaoRMRmK8Gl-uQK2VE-7w8y5XBqojIx4tyqGLl8XedwpfRyidlOSiqcoJ3Rjy4gH2k_wIkInfXz8rGKxoY3MbwELIIl9EhBS4q-tLUqqyQvAZZb7jImAGhSCXpkmuJqLkESrFnwmrg_r3OsHDQ',
#      'width': 1920}],
#    'place_id': 'ChIJ4RkcjG_keVwR-baCRVbZck0',
#    'plus_code': {'compound_code': '78JQ+WV Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78JQ+WV'},
#    'rating': 4.2,
#    'reference': 'ChIJ4RkcjG_keVwR-baCRVbZck0',
#    'scope': 'GOOGLE',
#    'types': ['electronics_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 96,
#    'vicinity': 'С. Васильева ул, дом 60, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.28226859999999, 'lng': 118.3404893},
#     'viewport': {'northeast': {'lat': 63.2837268802915,
#       'lng': 118.3417324802915},
#      'southwest': {'lat': 63.28102891970849, 'lng': 118.3390345197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'WESTERN UNION',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJh42Z1G_keVwRq0MlH7l2fQo',
#    'plus_code': {'compound_code': '78JR+W5 Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78JR+W5'},
#    'rating': 3,
#    'reference': 'ChIJh42Z1G_keVwRq0MlH7l2fQo',
#    'scope': 'GOOGLE',
#    'types': ['finance', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': "Ulitsa Stepana Vasil'yeva, 62, Nyurba"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2820428, 'lng': 118.3406808},
#     'viewport': {'northeast': {'lat': 63.2834220302915,
#       'lng': 118.3422516802915},
#      'southwest': {'lat': 63.28072406970849, 'lng': 118.3395537197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Pochta Rossii',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJL4px9G_keVwRtDzPXKWNbN4',
#    'plus_code': {'compound_code': '78JR+R7 Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78JR+R7'},
#    'rating': 4,
#    'reference': 'ChIJL4px9G_keVwRtDzPXKWNbN4',
#    'scope': 'GOOGLE',
#    'types': ['post_office', 'finance', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 50,
#    'vicinity': 'Ulitsa Khristofora Maksimova, 13, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.28706500000001, 'lng': 118.3354975},
#     'viewport': {'northeast': {'lat': 63.2884978302915,
#       'lng': 118.3368004802915},
#      'southwest': {'lat': 63.28579986970849, 'lng': 118.3341025197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'Administratsiya Mo "Bordonskiy Nasleg", Mku',
#    'place_id': 'ChIJAQB_LWnkeVwRTUA2M0MnIn0',
#    'plus_code': {'compound_code': '78PP+R5 Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78PP+R5'},
#    'reference': 'ChIJAQB_LWnkeVwRTUA2M0MnIn0',
#    'scope': 'GOOGLE',
#    'types': ['local_government_office', 'point_of_interest', 'establishment'],
#    'vicinity': 'Ulitsa Megezhekskogo, 4'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2802989, 'lng': 118.348134},
#     'viewport': {'northeast': {'lat': 63.2816550802915,
#       'lng': 118.3495528302915},
#      'southwest': {'lat': 63.27895711970849, 'lng': 118.3468548697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'name': 'Notarius',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105729700392347461507">Анисия Илларионова</a>'],
#      'photo_reference': 'CmRaAAAAtB05JjVvymE7pTyQpo0UOtCQIJs02BYiSGP2VG0d-L3yARj3sf_RazuKNQQxCCDiTjnsUABUC3h8_jI6Qv_EPhsdaU8sgU_2irH2BKCBCr8mLhroTb6fWVOc3w9KoyEnEhAPyJqGDrccl6yTyiZvdvczGhTudJ1VbJgZIko-MGFNAFBdaUOElA',
#      'width': 4000}],
#    'place_id': 'ChIJT-mDgHDkeVwRlBeO-ZZdos8',
#    'plus_code': {'compound_code': '78JX+47 Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78JX+47'},
#    'rating': 4.8,
#    'reference': 'ChIJT-mDgHDkeVwRlBeO-ZZdos8',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Ulitsa Pushkina, 13, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2881126, 'lng': 118.3432997},
#     'viewport': {'northeast': {'lat': 63.28933228029151, 'lng': 118.3439867},
#      'southwest': {'lat': 63.2866343197085, 'lng': 118.3412387}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'name': 'Nyurbinskiy Tekhnicheskiy Litsey Im. A.n. Chusovskogo',
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109845070446525667816">Сергей Иванов</a>'],
#      'photo_reference': 'CmRaAAAA5UUHDlSjAcY8wXtjeYYhjasJH-tgXdNHV59hsJu3fIqfch0SU2l99iWNUmLtrYAe5ClzmWA5Qk5A8lMI_gg64uP7fvPi2Dswq6YsATNbI70d5AAc2fSE_IgeoFdaFdllEhBoOyT-oMH-8Yzr3fk0SUqRGhTDzoNk2GZmxjfyKrYNFzBTgkEMxQ',
#      'width': 1080}],
#    'place_id': 'ChIJTYHtnW7keVwRBcui18VyvvA',
#    'plus_code': {'compound_code': '78QV+68 Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78QV+68'},
#    'rating': 4.9,
#    'reference': 'ChIJTYHtnW7keVwRBcui18VyvvA',
#    'scope': 'GOOGLE',
#    'types': ['school', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 9,
#    'vicinity': 'Ulitsa Korolenko, д 10, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.285448, 'lng': 118.3497272},
#     'viewport': {'northeast': {'lat': 63.28637913029151,
#       'lng': 118.3515484302915},
#      'southwest': {'lat': 63.2836811697085, 'lng': 118.3488504697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'name': 'МБОУ "Нюрбинская средняя общеобразовательная школа №2 имени М.С Егорова',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 364,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101455928545741152723">Yuu</a>'],
#      'photo_reference': 'CmRaAAAAymUMKch0yVNJyCHDtk1rwiPN91TxQvDSpNs2dOS00KKR9-UDaUy93GOd8qzG1suI2hWYVIw2qe2ihSWViSzAKHPNqZSedpXqSklp0P_PD0ZEAB286_lPaDVaYAqDAsIsEhAqlBgBtlhfWmVHBIpklkLOGhRURp8W9fnRBcV51DzbEeBhmrR0lg',
#      'width': 604}],
#    'place_id': 'ChIJ77S8-nHkeVwRt1gVmAUaDMA',
#    'plus_code': {'compound_code': '78PX+5V Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78PX+5V'},
#    'rating': 3.7,
#    'reference': 'ChIJ77S8-nHkeVwRt1gVmAUaDMA',
#    'scope': 'GOOGLE',
#    'types': ['school', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 15,
#    'vicinity': "Ulitsa Stepana Vasil'yeva, 83, Nyurba"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2857812, 'lng': 118.3072544},
#     'viewport': {'northeast': {'lat': 63.2870985802915,
#       'lng': 118.3085499802915},
#      'southwest': {'lat': 63.28440061970849, 'lng': 118.3058520197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'Gup Zhkkh Rs',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109204526592534746080">Николай Николаев</a>'],
#      'photo_reference': 'CmRaAAAAeKYL-XVzCWocjXb4NiJrMqLW7BjT6Dtj1GGHrrheuksMGjD7s8YtHS_uRMu-zBWbjGCu5dMhAd143zTmHTLZPXwM5qCSpgAw6DE-D2t5d4Xakx6o16ek2LekBNnLNo4WEhCFZbHkserAbUZIqG3rMKTqGhRHJSYQEfGhlc5R-q2TH8JLhDerrg',
#      'width': 3840}],
#    'place_id': 'ChIJK98YgFzkeVwRRfo7hw9ckIw',
#    'plus_code': {'compound_code': '78P4+8W Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78P4+8W'},
#    'reference': 'ChIJK98YgFzkeVwRRfo7hw9ckIw',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'vicinity': 'Ulitsa Manchary, 16, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.28400509999999, 'lng': 118.3030957},
#     'viewport': {'northeast': {'lat': 63.2852733802915,
#       'lng': 118.3045744802915},
#      'southwest': {'lat': 63.28257541970849, 'lng': 118.3018765197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#    'name': 'Go Gpps Mchs Rossii',
#    'place_id': 'ChIJDTzT-lvkeVwRohEWIQHCrRA',
#    'plus_code': {'compound_code': '78M3+J6 Nyurba, Sakha Republic, Russia',
#     'global_code': '9PMW78M3+J6'},
#    'rating': 5,
#    'reference': 'ChIJDTzT-lvkeVwRohEWIQHCrRA',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Ulitsa Chusovskogo, 12а, Nyurba'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 63.2803099, 'lng': 118.3618985},
#     'viewport': {'northeast': {'lat': 63.2819106802915,
#       'lng': 118.3631532802915},
#      'southwest': {'lat': 63.27921271970849, 'lng': 118.3604553197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/pharmacy-71.png',
#    'name': 'Аптека № 11',
#    'place_id': 'ChIJ_____3bkeVwRZv7Oy0VufOU',
#    'reference': 'ChIJ_____3bkeVwRZv7Oy0VufOU',
#    'scope': 'GOOGLE',
#    'types': ['pharmacy',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'vicinity': 'Nyurba'},
#   {'geometry': {'location': {'lat': 63.2859773, 'lng': 118.4048332},
#     'viewport': {'northeast': {'lat': 63.2928051, 'lng': 118.4304899},
#      'southwest': {'lat': 63.2792209, 'lng': 118.3775091}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#    'name': 'Antonovka',
#    'place_id': 'ChIJN-DaEPLjeVwRnChaXDevrQM',
#    'reference': 'ChIJN-DaEPLjeVwRnChaXDevrQM',
#    'scope': 'GOOGLE',
#    'types': ['locality', 'political'],
#    'vicinity': 'Antonovka'}],
#  'status': 'OK'}

# %%
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
parameters = {
    "radius" : 5000,
    "type" : "hotel",
    "key" : g_key
}
hotel_list = []
# for hotel in range(len(hotel_df)):
#     lat = hotel_df.loc[hotel]["Lat"]
#     lng = hotel_df.loc[hotel]["Lng"]
for index,row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    parameters["location"] = f"{lat}, {lng}"
    hotels = requests.get(url, params = parameters).json()
    
    try :
        # hotel_list.append(hotels["results"][0]["name"])
        hotel_df.loc[index,"Hotel Name"]=hotels["results"][0]["name"]
        print(f"Closest hotel is {hotels['results'][0]['name']} ")
    except:
        print("No hotel found")
                                  
# hotel_df["Hotel Name"] = hotel_list
# Out:
# Closest hotel is Hobart
# Closest hotel is Kaya
# Closest hotel is Ouahigouya
# Closest hotel is Segou
# Closest hotel is Kolondieba
# Closest hotel is Pokhara
# Closest hotel is Canindé
# Closest hotel is Kavaratti
# Closest hotel is Misrata
# Closest hotel is San
# Closest hotel is Karwar
# Closest hotel is Ouro Sogui
# Closest hotel is Mecca
# Closest hotel is San
# Closest hotel is Arlit
# Closest hotel is Kieta

# %%
# hotel_df =hotel_df.dropna()
hotel_df.head()

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
# marker_layer 
# fig = gmaps.figure(center=(20,1), zoom_level = 1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Add heat layer to fig 
fig.add_layer(marker_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
